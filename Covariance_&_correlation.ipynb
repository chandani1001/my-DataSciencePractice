# %% [markdown]
# <a href="https://colab.research.google.com/github/chandani1001/my-DataSciencePractice/blob/main/Covariance_%26_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Covariance & correlarion

# %% [markdown]
# defined  as the process to find out the relation between any 2 columns of the dataset. we use covariance & correalation.
# and able to choose the best algorithm .

# %% [markdown]
# **What is covariance:**
# It signifies the direction of the linear relationship between the two variables. by direction  we mean if the variable are directly proportional or inversely proportional to each other .
#
# range= -∞ to +∞

# %% [markdown]
# -- increasing the vslue of one variable might have a positive or a negative impact on the value of the other variable.

# %% [markdown]
# x ++ y++,
# x-- y++,
# x++ y

# %% [markdown]
# **Covariance ** has large data so the observation can be difficult so we use , Correlation.

# %% [markdown]
# #Correlation

# %% [markdown]
# *Correlation* analysis is a method of statisticaal evaluation used to study the strengh of a relationship between two, numerically measured, continous variable.
#
# range=-1to +1

# %% [markdown]
# ---
# divide the line into 4 parts
# (-1)-------(-0.5)-------(0)-------(0.5)------(1)
# (neg-strng)-(neg-weak)-(pov-weak)-(pov-strong)

# %%
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/tip.csv')

# %%
dataset.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# check for the null values

# %%
dataset.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# no null value present

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
dataset.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')

# %%
data_corr=dataset.select_dtypes(include=['int64','float64']).corr()
data_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
data_cov=dataset.select_dtypes(include=['int64','float64']).cov()
data_cov
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %% [markdown]
# Lets represent the data in the graph

# %%
sns.heatmap(dataset.select_dtypes(include=['int64','float64']).corr())
# Out:
# <Axes: >

# %% [markdown]
# *annot*=True is used to assign the numbers in the box

# %%
sns.heatmap(dataset.select_dtypes(include=['int64','float64']).corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data_cov,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# WE mustly use covaraince not correlation in the term of feature selection in ML
